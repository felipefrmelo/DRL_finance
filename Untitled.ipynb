# %%
from StockTradingEnv import StockTradingEnv
import pandas as pd
import numpy as np
import random
import torch
import matplotlib.pyplot as plt
import time
import datetime as dt

# %%
def get_data_alpha(symbols, dates, addSPY=True, colname = ['5. adjusted close']):
    
    from alpha_vantage.timeseries import TimeSeries
    
    ts = TimeSeries(key='ZZXPUWS3V96BN0OV', output_format='pandas')
    
    df = pd.DataFrame(index=dates)                                               
                           
    for symbol in symbols:                           
        df_temp,meta_data = ts.get_daily_adjusted(symbol=symbol, outputsize='full')                       
        df = df.join(df_temp)
        
        if symbol == 'SPY':  # drop dates SPY did not trade                           
            df = df.dropna(subset=["SPY"])                              
    
    return df

# %%
start_date = dt.datetime(2012, 1, 1) 
end_date = ed=dt.datetime(2019, 12, 31)
dates = pd.date_range(start_date, end_date)
Symbol = ['PETR4.SA']   
dict_order = {'Symbol': [], 'Order': [], 'Shares': [], 'Index': []}

prices = get_data_alpha(Symbol, dates, False)
prices.dropna(inplace=True)

# %%
df = prices.rename(columns={column:column.split('.')[1].strip() for column in prices.columns })

# %%
'  wsds sdsds'.strip()
# Out:
# 'wsds sdsds'

# %%
from ddpg_agent import Agent

from collections import deque

# Create simulation environment
# df = pd.read_csv('./data/AAPL_2018.csv')
env = StockTradingEnv(df)
n_trades = 1000
# Initialize Feed-forward DNNs for Actor and Critic models. 
agent = Agent(state_size=env.observation_space.shape[1] , action_size=3, random_seed=0)

# Set the number of episodes to run the simulation
episodes = 1000
scores = []                        # list containing scores from each episode
scores_window = deque(maxlen=100)  # last 100 scores
best_avg = -np.inf

for episode in range(episodes): 
    # Reset the enviroment
    state = env.reset()
    score = 0
    # set the environment to make transactions
    for i in range(n_trades + 1):
      
        # Predict the best action for the current state. 
        action = agent.act(state, add_noise = True)
        
        # Action is performed and new state, reward, info are received. 
        new_state, reward, done, info = env.step(np.argmax(action))
        
        # current state, action, reward, new state are stored in the experience replay
        agent.step(state, action, reward, new_state, done)
        
        # roll over new state
        state = new_state
        score += reward      
        if done:
            break
        
    scores_window.append(score)       # save most recent score
    scores.append(score)              # save most recent score
    avg_score = np.mean(scores_window)
    if (episode + 1) % 100 == 0:
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(episode, np.mean(scores_window)))
        env.render()
    if avg_score > best_avg:
        best_avg = avg_score
        torch.save(agent.actor_local.state_dict(), 'checkpoint' + '.pth')    
        if avg_score >= 5080.0:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(episode, np.mean(scores_window)))
            torch.save(agent.actor_local.state_dict(), 'checkpoint' + '.pth')

print('\nAverage Implementation Shortfall: ${:,.2f} \n'.format(np.mean(shortfall_hist)))
# Out:
# start episode ... at step 1729
# Tick: 1800/ Portfolio (krw-won): 12038.165845685668
# Long: 3/ Short: 5
# start episode ... at step 71
# Tick: 100/ Portfolio (krw-won): 8698.431277803524
# Long: 0/ Short: 0
# Tick: 200/ Portfolio (krw-won): 10300.164764828547
# Long: 0/ Short: 0
# Tick: 300/ Portfolio (krw-won): 8624.362677247453
# Long: 0/ Short: 0
# Tick: 400/ Portfolio (krw-won): 8254.0196744671
# Long: 0/ Short: 0
# Tick: 500/ Portfolio (krw-won): 7392.972193002784
# Long: 0/ Short: 0
# Tick: 600/ Portfolio (krw-won): 8184.5803614457855
# Long: 0/ Short: 0
# Tick: 700/ Portfolio (krw-won): 6490.261123725673
# Long: 0/ Short: 0
# Tick: 800/ Portfolio (krw-won): 4333.013132530122
# Long: 0/ Short: 0
# Tick: 900/ Portfolio (krw-won): 3842.3086538461557
# Long: 0/ Short: 0
# Tick: 1000/ Portfolio (krw-won): 2050.774377896201
# Long: 0/ Short: 0
# start episode ... at step 1229
# Tick: 1300/ Portfolio (krw-won): 10345.295475941424
# Long: 0/ Short: 0
# Tick: 1400/ Portfolio (krw-won): 9669.542168758719
# Long: 0/ Short: 0
# Tick: 1500/ Portfolio (krw-won): 12086.9277109484
# Long: 0/ Short: 0
# Tick: 1600/ Portfolio (krw-won):
# Long: 0/ Short: 0
# Tick: 1300/ Portfolio (krw-won): 8610.071800638423
# Long: 0/ Short: 0
# Tick: 1400/ Portfolio (krw-won): 8047.663070226352
# Long: 0/ Short: 0
# start episode ... at step 1715
# Tick: 1800/ Portfolio (krw-won): 11206.279400118205
# Long: 0/ Short: 0
# start episode ... at step 1029
# Tick: 1100/ Portfolio (krw-won): 11521.712516960653
# Long: 0/ Short: 0
# Tick: 1200/ Portfolio (krw-won): 23097.64485753053
# Long: 0/ Short: 0
# Tick: 1300/ Portfolio (krw-won): 20129.109514925374
# Long: 0/ Short: 0
# Tick: 1400/ Portfolio (krw-won): 18814.27879240163
# Long: 0/ Short: 0
# Tick: 1500/ Portfolio (krw-won): 23517.848490502038
# Long: 0/ Short: 0
# Tick: 1600/ Portfolio (krw-won): 20888.187045454546
# Long: 0/ Short: 0
# Tick: 1700/ Portfolio (krw-won): 37032.13952510177
# Long: 0/ Short: 0
# Tick: 1800/ Portfolio (krw-won): 38590.95945386703
# Long: 0/ Short: 0
# start episode ... at step 151
# Tick: 200/ Portfolio (krw-won): 10584.645505952383
# Long: 0/ Short: 0
# Tick: 300/ Portfolio (krw-won): 8862.559360714287
# Long: 0/ Short: 0
# Tick: 400/ Portfolio (krw-won): 8481.987836904762
# Long: 0/ Short: 0
# Tick: 500/ Portfolio (krw-won): 7597.159044047621
# Long: 0/ Short: 0
# Tick: 600/ Portfolio (krw-won): 8410.630676190478
# Long: 0/ Short: 0
# Tick: 700/ Portfolio (krw-won): 6669.515954761905
# Long: 0/ Short: 0
# Tick: 800/ Portfolio (krw-won): 4452.686828571429
# Long: 0/ Short: 0
# Tick: 900/ Portfolio (krw-won): 3948.4295595238104
# Long: 0/ Short: 0

# %%
info

# %%
 action = agent.act(state, add_noise = True)

# %%
action

# %%
agent.critic_local

# %%
agent.s

# %%
env.action_space.sample()

# %%
env.current_tick

# %%
env.observation_space.shape[1]

# %%
state

# %%
agent.critic_local(state,[1,2,3])

# %%
def visualize(info, show_limit=1000):
    history = info['history'][-show_limit:]
    closes = [data[2] for data in history]
    closes_index = [data[1] for data in history]
    # buy tick
    buy_tick = np.array([data[1] for data in history if data[0] == 0])
    buy_price = np.array([data[2] for data in history if data[0] == 0])
    sell_tick = np.array([data[1] for data in history if data[0] == 1])
    sell_price = np.array([data[2] for data in history if data[0] == 1])

    plt.figure(figsize=(14,10)) # change the figure size
    plt.plot(closes_index, closes)
    plt.scatter(buy_tick, buy_price , c='g', marker="^", s=25)
    plt.scatter(sell_tick, sell_price , c='r', marker="v", s=25)
    plt.show(block=True)
    time.sleep(3)

# %%
visualize(info, show_limit=15000)
visualize(info, show_limit=1000)

# %%
# plot cumulative return and max drawdown
def show_mdd(info): # xs is cumulative return / portfolio , if reward u should
    reward_history = [data[4] for data in info['history']]
    df = pd.DataFrame()
    df['reward'] = reward_history
    df['cum_reward'] = df['reward'].cumsum()
    xs = df['cum_reward'].values
    
    i = np.argmax(np.maximum.accumulate(xs) - xs) # end of the period
    j = np.argmax(xs[:i]) # start of period
    plt.figure(figsize=(16,10))
    plt.plot(xs)
    plt.plot([i, j], [xs[i], xs[j]], 'o', color='Red', markersize=10)
    plt.show()
    return xs[-1]
total_return = show_mdd(info)
print("total cumulative return : ",total_return)
print("portfolio value {0} -> {1}" .format(100*10000, info['portfolio']))
